# %% [markdown]
# # Demo

# %%
from exp1 import main as exp1_plt
from exp2 import main as exp2_plt
from exp3 import main as exp3_plt
from exp4 import main as exp4_plt

# %%
exp1_plt()
# Out:
# Testing RD model with n = 128, ds_parameter = 1 on 0-th trajectory
# 0.02
# /Users/zhaojiaxi/zjx@pku/Math/python_code/ML/dynamics system/TR 4 MLDS/TR/exp/simulator.py:149: RuntimeWarning: invalid value encountered in add
#   self.u = (self.A0 @ self.u.reshape([self.n*self.n, 1])).reshape([self.n, self.n]) + self.dt * output[0, 0, :, :]
# Testing RD model with n = 128, ds_parameter = 1 on 0-th trajectory
# 0.02
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:397: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:398: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:410: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/numpy/ma/core.py:722: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:397: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:398: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:410: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/numpy/ma/core.py:722: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:397: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:398: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/matplotlib/image.py:410: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/numpy/ma/core.py:722: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)

# %%
exp2_plt()

# %%
exp3_plt()
# Out:
# usage: ipykernel_launcher.py [-h] [--type TYPE] [--gamma GAMMA] [--Re RE]
#                              [--n N] [--batch_size BATCH_SIZE] [--GPU GPU]
# ipykernel_launcher.py: error: unrecognized arguments: --ip=127.0.0.1 --stdin=9008 --control=9006 --hb=9005 --Session.signature_scheme="hmac-sha256" --Session.key=b"3f040375-23e5-4e88-af4c-170a357f37fa" --shell=9007 --transport="tcp" --iopub=9009 --f=/Users/zhaojiaxi/Library/Jupyter/runtime/kernel-v2-903Ls9NtI16hcb5.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/zhaojiaxi/anaconda3/envs/Applymath/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
exp4_plt()

# %%
import numpy as np

gamma = 0.5
u = np.power(0.005, 1/3)
a = (1-6*u**2)/gamma
b = 3*u**2/gamma**2
print(a)
print(b)

print((a+np.sqrt(a**2-4*b))/2)
print((a-np.sqrt(a**2-4*b))/2)
# Out:
# 1.6491178714144559
# 0.3508821285855441
# 1.3981574973067952
# 0.2509603741076608
